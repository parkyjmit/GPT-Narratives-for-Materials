# %%
import pandas as pd

# %%
df = pd.read_parquet('/mnt/hdd1/LaMDa/mp_3d_2020_gpt_narratives.parquet')

# %%
df
# Out:
#                                                     atoms space group symbol  \
# 0       {'abc': [7.833244, 7.833245, 7.83325], 'angles...              Fm-3m
# 1       {'abc': [2.93071, 2.93071, 2.93071], 'angles':...              Pm-3m
# 2       {'abc': [4.10291, 5.36576, 6.94965], 'angles':...               Pnma
# 3       {'abc': [3.030575, 6.390968, 12.03601], 'angle...                 P1
# 4       {'abc': [8.411952, 8.411952, 8.411950000000001...                 R3
# ...                                                   ...                ...
# 126330  {'abc': [5.17955, 5.179548, 15.91706], 'angles...               Cmcm
# 126331  {'abc': [7.898652, 7.898655, 17.29874], 'angle...                 C2
# 126332  {'abc': [5.937475, 5.937468, 6.71117], 'angles...               C2/m
# 126333  {'abc': [5.63421, 5.420895, 9.40086], 'angles'...             P2_1/c
# 126334  {'abc': [8.79866, 7.380193, 9.73546], 'angles'...             P2_1/c
#
# ...

# %%
df['gpt_text'].iloc[-1]
# Out:
# 'The substance stored in the database has the chemical formula ZnFeAs2O7 and is categorized as an oxide. The crystal system of this material is monoclinic, and its space group symbol is P2_1/c. The substance has a density of 4.410696 g/cm^3 and a volume of 576.907479 A^3.   The energy per atom of the substance is -5.76915 eV, and its formation energy per atom is -1.584384 eV. The energy above hull is 0.19065 eV, and the band gap of this material is 1.1913 eV.   The substance has a total magnetization of 0.0 emu/g and an enthalpy per atom of -5.545057 eV. Its scintillation attenuation length is 2.777525 cm, and it is noted as unstable or not thermodynamically stable, with a value of "False" in the stable column.  In summary, this is a monoclinic oxide material with the chemical formula ZnFeAs2O7 having a density of 4.410696 g/cm^3 and a volume of 576.907479 A^3. It has a moderate band gap of 1.1913 eV, energy per atom of -5.76915 eV, and is unstable with formation energy per atom of -
# ...
